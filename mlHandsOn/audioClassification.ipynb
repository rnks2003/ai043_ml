# %% [markdown]
# **Import dependencies :**

# %%
#pip install librosa
#pip install -U spafe
#check spafe
# Out:
# Collecting spafe
#   Downloading spafe-0.3.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy>=1.21 in /home/ailab/anaconda3/envs/ai043_ml/lib/python3.10/site-packages (from spafe) (1.26.4)
# Requirement already satisfied: scipy>=1.7.3 in /home/ailab/anaconda3/envs/ai043_ml/lib/python3.10/site-packages (from spafe) (1.13.0)
# Requirement already satisfied: typing-extensions in /home/ailab/anaconda3/envs/ai043_ml/lib/python3.10/site-packages (from spafe) (4.11.0)
# Downloading spafe-0.3.2-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: spafe
# Successfully installed spafe-0.3.2

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import scipy

# %% [markdown]
# **Load Audio file :**

# %%
aud = "../datasets/audio/StarWars3.wav"

# %%
y, sr = librosa.load(aud)

# %% [markdown]
# **Compute MFCC :**

# %%
mfccs = librosa.feature.mfcc(y=y,sr=sr,n_mfcc=13)

# %% [markdown]
# **Visualise MFCC :**

# %%
plt.figure(figsize=(10,5))
librosa.display.specshow(mfccs, x_axis='time',cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.xlabel('Time')
plt.ylabel('MFCC Coefficients')
plt.show()

# %% [markdown]
# **compute LPC :**

# %%
a = librosa.lpc(y, order=2)
b = np.hstack([[0], -1 * a[1:]])
y_hat = scipy.signal.lfilter(b, [1], y)

# %%
fig, ax = plt.subplots()
ax.plot(y)
ax.plot(y_hat, linestyle='--')
ax.legend(['y', 'y_hat'])
ax.set_title('LP Model Forward Prediction')
# Out:
# Text(0.5, 1.0, 'LP Model Forward Prediction')
